# %%
## 2. Keep Approximating
## Part (b,c,d)

f = tan(x)
f_1 = diff(f)
f_2 = diff(f_1)
f_3 = diff(f_2)

L(x) = f(0) + x * f_1(0) 
Q(x) = f(0) + x * f_1(0) + (x^2/2) * f_2(0)
C(x) = f(0) + x * f_1(0) + (x^2/2) * f_2(0) + (x^3/6) * f_3(0)

# %%
show(f)
show(L)
show(Q)
show(C)
# Out:
# tan(x)
# x |--> x
# x |--> x
# x |--> 1/3*x^3 + x

# %%
plot1 = plot(f,-1,1, legend_label="Original Function", axes_labels=['$x$','$y$'], legend_color = 'blue')
plot2 = plot(L, -1,1, color='green', legend_label="Linear Approximation", legend_color = 'green')
plot1 + plot2
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
plot1 = plot(f,-1,1, legend_label="Original Function", axes_labels=['$x$','$y$'], legend_color = 'blue')
plot2 = plot(Q, -1,1, color='green', legend_label="Quadratic Approximation", legend_color = 'green')
plot1 + plot2
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
plot1 = plot(f,-1,1, legend_label="Original Function", axes_labels=['$x$','$y$'], legend_color = 'blue')
plot2 = plot(C, -1,1, color='green', legend_label="Cubic Approximation", legend_color = 'green')
plot1 + plot2
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
## Part (e)

# %%
taylor = []
for i in range(1,7):
    taylor.append(f.taylor(x,0,i))
    print('Taylor Polynomial of order:', i)
    show(taylor[i-1])
# Out:
# ('Taylor Polynomial of order:', 1)
# x
# ('Taylor Polynomial of order:', 2)
# x
# ('Taylor Polynomial of order:', 3)
# 1/3*x^3 + x
# ('Taylor Polynomial of order:', 4)
# 1/3*x^3 + x
# ('Taylor Polynomial of order:', 5)
# 2/15*x^5 + 1/3*x^3 + x
# ('Taylor Polynomial of order:', 6)
# 2/15*x^5 + 1/3*x^3 + x

# %%
## plotting all 6 taylor polymoials together
plot1 = plot(f, -6 ,6, ymin=-10, ymax=10,
             legend_label="Original Function", axes_labels=['$x$','$y$'], legend_color = 'blue')
plot2 = plot(taylor[1], -6, 6, ymin=-10, ymax=10,
             legend_label="1st and 2nd Degree Taylor Polynomial", color = 'green', legend_color = 'green')
plot3 = plot(taylor[3], -6, 6, ymin=-10, ymax=10,
             legend_label="3rd and 4th Degree Taylor Polynomial", color = 'orange', legend_color = 'orange')
plot4 = plot(taylor[5], -6, 6, ymin=-10, ymax=10,
             legend_label="5th and 6th Degree Taylor Polynomial", color = 'red', legend_color = 'red')

plot1.set_legend_options(loc = 'lower right')
plot1+plot2+plot3+plot4
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
## plotting all 6 taylor polymoials together
plot1 = plot(f, -1 ,1, 
             legend_label="Original Function", axes_labels=['$x$','$y$'], legend_color = 'blue')
plot2 = plot(taylor[1], -1 ,1,
             legend_label="1st and 2nd Degree Taylor Polynomial", color = 'green', legend_color = 'green')
plot3 = plot(taylor[3], -1 ,1, 
             legend_label="3rd and 4th Degree Taylor Polynomial", color = 'orange', legend_color = 'orange')
plot4 = plot(taylor[5], -1 ,1, 
             legend_label="5th and 6th Degree Taylor Polynomial", color = 'red', legend_color = 'red')

plot1.set_legend_options(loc = 'lower right')
plot1+plot2+plot3+plot4
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
## plotting all 6 taylor polymoials together
plot1 = plot(f, 1.6, 3.14, 
             legend_label="Original Function", axes_labels=['$x$','$y$'], legend_color = 'blue')
plot2 = plot(taylor[1], 1.6, 3.14,
             legend_label="1st and 2nd Degree Taylor Polynomial", color = 'green', legend_color = 'green')
plot3 = plot(taylor[3], 1.6, 3.14,
             legend_label="3rd and 4th Degree Taylor Polynomial", color = 'orange', legend_color = 'orange')
plot4 = plot(taylor[5], 1.6, 3.14,
             legend_label="5th and 6th Degree Taylor Polynomial", color = 'red', legend_color = 'red')

plot1.set_legend_options(loc = 'lower right')
plot1+plot2+plot3+plot4
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
## plotting all 6 taylor polymoials together
plot1 = plot(f, -3.14 ,-1.6, 
             legend_label="Original Function", axes_labels=['$x$','$y$'], legend_color = 'blue')
plot2 = plot(taylor[1], -3.14 ,-1.6,
             legend_label="1st and 2nd Degree Taylor Polynomial", color = 'green', legend_color = 'green')
plot3 = plot(taylor[3], -3.14 ,-1.6,
             legend_label="3rd and 4th Degree Taylor Polynomial", color = 'orange', legend_color = 'orange')
plot4 = plot(taylor[5], -3.14 ,-1.6,
             legend_label="5th and 6th Degree Taylor Polynomial", color = 'red', legend_color = 'red')

plot1.set_legend_options(loc = 'lower right')
plot1+plot2+plot3+plot4
# Out:
# Graphics object consisting of 4 graphics primitives

# %% [markdown]
# ### 2.g. Normal Distribution N(0,1)

# %%
f(x) = 1/(2*pi)**0.5 * e^(-x^2/2)

f_1 = f.taylor(x,0,1)
f_2 = f.taylor(x,0,2)
f_3 = f.taylor(x,0,3)

# %%
show(f_1)
show(f_2) 
show(f_3)
# Out:
# x |--> 0.3989422804014326
# x |--> -0.1994711402007163*x^2 + 0.3989422804014326
# x |--> -0.1994711402007163*x^2 + 0.3989422804014326

# %%
n(1/(2*pi)**0.5)
# Out:
# 0.398942280401433

# %%
n(1/(2*pi)**0.5)/2
# Out:
# 0.199471140200716

# %%
plot1 = plot(f, -1,1, legend_label="Original Function", axes_labels=['$x$','$y$'], legend_color = 'blue')
plot2 = plot(f_1, -1, 1, legend_label="1st Degree Taylor Polynomial", color = 'green', legend_color = 'green')
plot1+plot2
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
plot1 = plot(f, -1,1, legend_label="Original Function", axes_labels=['$x$','$y$'], legend_color = 'blue')
plot2 = plot(f_2, -1, 1, legend_label="2nd Degree Taylor Polynomial", color = 'green', legend_color = 'green')
plot1+plot2
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
plot1 = plot(f, -1,1, legend_label="Original Function", axes_labels=['$x$','$y$'], legend_color = 'blue')
plot2 = plot(f_3, -1, 1, legend_label="3rd Degree Taylor Polynomial", color = 'green', legend_color = 'green')
plot1+plot2
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
print(integrate(f_1,x,-1,1))
print(integrate(f_2,x,-1,1))
print(integrate(f_3,x,-1,1))
print(integrate(f,x,-1,1)).n()
# Out:
# 0.7978845608028652
# 0.6649038006690543
# 0.6649038006690543
# 0.682689492137086

# %%
plot1 = plot(f, -10,10, legend_label="Original Function", axes_labels=['$x$','$y$'], legend_color = 'blue')
plot2 = plot(f_1, -10, 10, legend_label="1st Degree Taylor Polynomial", color = 'green', legend_color = 'green')
plot1+plot2
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
plot1 = plot(f, -10,10, legend_label="Original Function", axes_labels=['$x$','$y$'], legend_color = 'blue')
plot2 = plot(f_2, -10, 10, legend_label="2nd Degree Taylor Polynomial", color = 'green', legend_color = 'green')
plot1+plot2
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
plot1 = plot(f, -10, 10, legend_label="Original Function", axes_labels=['$x$','$y$'], legend_color = 'blue')
plot2 = plot(f_3, -10, 10, legend_label="3rd Degree Taylor Polynomial", color = 'green', legend_color = 'green')
plot1+plot2
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
print(integrate(f_1,x,-1000,1000))
print(integrate(f_2,x,-1000,1000))
print(integrate(f_3,x,-1000,1000))
print(integrate(f,x,-1000,1000)).n()
# Out:
# 797.8845608028652
# -132979962.24925004
# -132979962.24925004
# 1.00000000000000

# %% [markdown]
# ### 2.f. Method For Programming a Calculator
#
# Testing and prototyping the pseoudocode

# %%
# Part (f)
# testing phase

g(x) = sin(x)
g_10 = g.taylor(x,0,10)
plot1 = plot(g,-5,5, legend_label="Original Function", axes_labels=['$x$','$y$'], legend_color = 'blue')
plot2 = plot(g_10, -5, 5, legend_label="10th Degree Taylor Polynomial", color = 'green', legend_color = 'green')
plot1+plot2
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
g_20 = g.taylor(x,0,20)
plot1 = plot(g,-8,8, legend_label="Original Function", axes_labels=['$x$','$y$'], legend_color = 'blue')
plot2 = plot(g_20, -8, 8, legend_label="20th Degree Taylor Polynomial", color = 'green', legend_color = 'green')
plot1+plot2
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
## Functions:  prototyping phase

f = sin(x)
f_1000 = f.taylor(x,0,1000)

# %%
def my_sin_1(x):
    return f_1000(x)

# %%
def my_sin_2(xx):
    if xx == 0: 
        return 0
    else:
        taylor = f.taylor(x,0,int(abs(xx*4)))
        return (taylor(xx))

# %%
## Check the functions

sin(-30.0)
# Out:
# 0.988031624092862

# %%
my_sin_1(-30.0)
# Out:
# /opt/sagemath-8.8/local/lib/python2.7/site-packages/sage/repl/ipython_kernel/__main__.py:1: DeprecationWarning: Substitution using function-call syntax and unnamed arguments is deprecated and will be removed from a future release of Sage; you can use named arguments instead, like EXPR(x=..., y=...)
# See http://trac.sagemath.org/5930 for details.
#   from ipykernel.kernelapp import IPKernelApp
# 0.988152266669703

# %%
my_sin_2(-30.0)
# Out:
# /opt/sagemath-8.8/local/lib/python2.7/site-packages/sage/repl/ipython_kernel/__main__.py:1: DeprecationWarning: Substitution using function-call syntax and unnamed arguments is deprecated and will be removed from a future release of Sage; you can use named arguments instead, like EXPR(x=..., y=...)
# See http://trac.sagemath.org/5930 for details.
#   from ipykernel.kernelapp import IPKernelApp
# 0.988152266669703
